# %%
pip install openpyxl
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 242.1/242.1 kB 3.7 MB/s eta 0:00:00a 0:00:01
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %%
ls
# Out:
# 1_China_solar panel.png
# 2020-National-Solar-Jobs-Census-Chart-Data-Public.xlsx
# ENERGÍA SOLAR FOTOVOLTAICA_Ayuntamiento de Madrid.xlsx
# ENSPRESO_SOLAR_PV_CSP (1).xlsx
# ENSPRESO_SOLAR_PV_CSP.xlsx
# Energy from renewable UE.xlsx
# Hydro provisional 2020 (1).xlsx
# Hydro provisional 2020.xlsx
# Indicadores_SE_CCAA_DIC2017_v2.xlsm
# NP_Avance_Informe Sistema Electrico_2021_Nacional.pdf
# Nacional/
# Presentacion_Avance2021_17032022_18.30.pdf
# Renewable_energy-tables_and_figures_2022-January_final.xlsx
# SHARES 2020 detailed results (1).zip
# SHARES 2020 detailed results.zip
# Solar_Power_Europe_Global_Market_Outlook_report_2022_2022_V2_07aa98200a.pdf
# Untitled.ipynb
# energiaDisponible_aprov_consumo.tsv
# nrg_ind_ured.sdmx.zip
# online_setplan_template_report_2021_1.pdf
# renewable energy in gross final energy consumption by sector.xlsx
# renewable energy source in electricity.xls
# renewable energy source.xls
# seguimientoDemandaEnergia.csv
# solar_pv_capacity_country.xlsx
# ...

# %%
renewable_source = pd.read_excel('Energy from renewable UE.xlsx')

# %%
renewable_source.head(60)
# Out:
#                                                  TIME    2011    2012    2013  \
# 0                                        GEO (Labels)     NaN     NaN     NaN
# 1           European Union - 27 countries (from 2020)  14.547  16.002  16.660
# 2               Euro area - 19 countries  (from 2015)  13.114  14.604  15.228
# 3                                             Belgium   6.302   7.086   7.671
# 4                                            Bulgaria  14.152  15.837  18.898
# 5                                             Czechia  10.945  12.814  13.927
# 6                                             Denmark  23.389  25.465  27.173
# 7    Germany (until 1990 former territory of the FRG)  12.470  13.549  13.760
# 8                                             Estonia  25.515  25.586  25.356
# 9                                             Ireland   6.605   7.029   7.521
# 10                                             Greece  11.153  13.741  15.326
# ...

# %%
ls
# Out:
# ENSPRESO_SOLAR_PV_CSP.xlsx
# Energy from renewable UE.xlsx
# Hydro provisional 2020.xlsx
# SHARES 2020 detailed results.zip
# Untitled.ipynb
# nrg_ind_esc.tsv
# nrg_ind_esc.tsv.gz
# online_setplan_template_report_2021_1.pdf
# renewable energy in gross final energy consumption by sector.xlsx
# ~$ENSPRESO_SOLAR_PV_CSP.xlsx

# %%
df = pd.read_csv('nrg_ind_esc.tsv', sep ='\t')

# %%
df
# Out:
#      siec,nrg_bal,unit,geo\time    2019     2018     2017     2016     2015   \
# 0          TOTAL,FC_E,GJ_HAB,AL    30.3     31.1     30.3     27.7     28.6
# 1          TOTAL,FC_E,GJ_HAB,AT   123.1    122.7    125.5    124.2    122.1
# 2          TOTAL,FC_E,GJ_HAB,BA       :        :     41.9     42.3     39.5
# 3          TOTAL,FC_E,GJ_HAB,BE   118.1    120.9    120.7    122.9    122.3
# 4          TOTAL,FC_E,GJ_HAB,BG    58.6     58.5     58.1     56.3     55.1
# ...                         ...      ...      ...      ...      ...      ...
# 2183    TOTAL,NRGSUP,TOE_HAB,SK  3.1103   3.1165   3.1592   2.9960   2.9869
# 2184    TOTAL,NRGSUP,TOE_HAB,TR  1.7462   1.7460   1.8029   1.6944   1.6232
# 2185    TOTAL,NRGSUP,TOE_HAB,UA  2.1532   2.2349   2.1263   2.1672   2.1879
# 2186    TOTAL,NRGSUP,TOE_HAB,UK       :   2.6037   2.6267   2.6850   2.7435
# 2187    TOTAL,NRGSUP,TOE_HAB,XK       :   1.4433   1.4260   1.5072   1.4178
#
# ...

# %%
ls
# Out:
# ENSPRESO_SOLAR_PV_CSP.xlsx
# Energy from renewable UE.xlsx
# Hydro provisional 2020.xlsx
# SHARES 2020 detailed results.zip
# Untitled.ipynb
# aei_pr_soiler.tsv
# aei_pr_soiler.tsv.gz
# energiaDisponible_aprov_consumo.tsv
# online_setplan_template_report_2021_1.pdf
# renewable energy in gross final energy consumption by sector.xlsx
# ~$ENSPRESO_SOLAR_PV_CSP.xlsx

# %%
df2 =  pd.read_csv('aei_pr_soiler.tsv', sep ='\t')
df2
# Out:
#                  levels,clc18,unit,geo\time     2016      2010      2000
# 0                       MOD,CLC23_321,HA,AT  390499.0  390075.0  351481.0
# 1                     MOD,CLC23_321,HA,AT11     599.0     600.0     621.0
# 2                    MOD,CLC23_321,HA,AT111     112.0     112.0     104.0
# 3                    MOD,CLC23_321,HA,AT112      65.0      66.0      88.0
# 4                    MOD,CLC23_321,HA,AT113     422.0     422.0     429.0
# ...                                     ...       ...       ...       ...
# 130795  TOTAL,CLC2_3X331_332_335,T_HA,UKN12       0.8       0.8       0.9
# 130796  TOTAL,CLC2_3X331_332_335,T_HA,UKN13       0.7       0.7       0.7
# 130797  TOTAL,CLC2_3X331_332_335,T_HA,UKN14       0.7       0.8       0.8
# 130798  TOTAL,CLC2_3X331_332_335,T_HA,UKN15       1.0       1.1       1.3
# 130799  TOTAL,CLC2_3X331_332_335,T_HA,UKN16       0.6       0.7       0.7
#
# [130800 rows x 4 columns]
